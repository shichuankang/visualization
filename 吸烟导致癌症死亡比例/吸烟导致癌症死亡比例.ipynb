# %%
import pandas as pd
df=pd.read_csv("C:/Users/我我我/Desktop/smoke_cancer.csv")

# %%
df
# Out:
#                              国家  2012  2013  2014  2015  2016  2017
# 0                   Afghanistan  19.3  19.1  18.6  18.9  19.4  20.3
# 1                       Albania  29.3  29.4  31.8  29.7  28.1  28.0
# 2                       Algeria  15.9  14.5  10.0   9.3   7.5   7.4
# 3                American Samoa  24.2  23.6  22.6  22.8  21.6  22.4
# 4                       Andorra  23.2  22.4  22.0  22.3  21.8  22.4
# 5                        Angola  10.1   9.5   8.6   8.2   8.8  10.2
# 6           Antigua and Barbuda   8.1   7.5   7.1   6.0   5.7   5.2
# 7                     Argentina  24.7  24.4  23.5  22.7  22.4  22.0
# 8                       Armenia  28.7  29.8  29.4  31.5  32.4  29.2
# 9                   Australasia  27.6  26.7  25.6  25.0  24.3  23.3
# 10                    Australia  27.3  26.6  25.6  25.1  24.4  23.5
# 11                      Austria  25.2  25.2  25.0  25.6  26.1  24.7
# 12                   Azerbaijan  25.7  22.9  20.5  20.1  22.5  22.2
# ...

# %%
death=zip(list(df.国家),(df['2017']))
print(death)

# %%
df['2017'].max()
# Out:
# 57.1

# %%
df['2017'].min()
# Out:
# 2.2

# %%
from pyecharts import options as opts
from pyecharts.charts import Map

def map_world() -> Map:
    c = (
        Map()
        .add("死亡比例", [list(z) for z in zip(list(df.国家),(df['2017']))], "world")
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="吸烟导致癌症死亡比例"),
            visualmap_opts=opts.VisualMapOpts(max_=57.1,min_=2.2),
        )
    )
    return c

# %%
map_world().render(path="吸烟导致癌症死亡比例.html")
# Out:
# 'C:\\Users\\我我我\\Desktop\\吸烟导致癌症死亡比例.html'

# %% [markdown]
# # 吸烟导致癌症死亡的比例
# ### 该地图显示了因吸烟导致的癌症死亡的比例，可以看出全球超过五分之一的癌症死亡是吸烟导致的。
# ### 美国，加拿大等发达国家吸烟导致癌症死亡比例普遍较高。
# ### 而一些较为落后的国家，吸烟导致的癌症死亡比例较低。
